# %%
import numpy as np

# %%
arr = np.array([3,4,2,33])

# %%
arr
# Out:
# array([ 3,  4,  2, 33])

# %%
np.mean(arr)
# Out:
# np.float64(10.5)

# %%
np.min(arr)
# Out:
# np.int64(2)

# %%
np.max(arr)
# Out:
# np.int64(33)

# %%
np.std(arr)
# Out:
# np.float64(13.009611831257688)

# %%
np.var(arr)
# Out:
# np.float64(169.25)

# %%
np.sum(arr)
# Out:
# np.int64(42)

# %%
np.prod(arr)
# Out:
# np.int64(792)

# %%
np.percentile(arr,50)
# Out:
# np.float64(3.5)

# %%
np.argmin(arr)  #gives minimmum element index
# Out:
# np.int64(2)

# %%
np.argmax(arr)
# Out:
# np.int64(3)

# %%
np.median(arr)
# Out:
# np.float64(3.5)

# %%
arr2 = np.array([43,56,87,90])

# %%
np.corrcoef(arr,arr2)
# Out:
# array([[1.        , 0.57374584],
#        [0.57374584, 1.        ]])

# %%
np.unique(arr)  #find unique element in array
# Out:
# array([ 2,  3,  4, 33])

# %%
np.diff(arr)  #compute nth difference of an array
# Out:
# array([ 1, -2, 31])

# %%
np.cumsum(arr)  #calculate cumulative sum of an array
# Out:
# array([ 3,  7,  9, 42])

# %%
np.linspace(0,10,5)   #Create an array with evenly spaced numbers over a specified interval.
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)  #compute the natural logarithm of an rray
# Out:
# array([1.09861229, 1.38629436, 0.69314718, 3.49650756])

# %%
np.exp(arr)   #compute the exponential of an array
# Out:
# array([2.00855369e+01, 5.45981500e+01, 7.38905610e+00, 2.14643580e+14])
