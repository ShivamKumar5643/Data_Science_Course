# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
result = arr ** 2  #vectorization operation
print(result)
# Out:
# [ 1  4  9 16 25]

# %%
result + 10          #broadcast ()
# Out:
# array([21, 32, 43])

# %%
arr1 = np.array([1,2,3])
arr2= np.array([10,20,30])
resultt = arr1 + arr2

# %%
resultt
# Out:
# array([11, 22, 33])

# %%
arr2d = np.array([[1,2,3],[4,5,6]])
arr1d = np.array([1,2,3])
ans = arr2d + arr1d

# %%
ans
# Out:
# array([[2, 4, 6],
#        [5, 7, 9]])

# %% [raw]
# Hands on example(Normalizing Data Using Broadcasting)

# %%
data = np.array([[10,20,30],
                 [15,25,35],
                 [20,30,40],
                 [25,35,45],
                 [30,40,50]])

# %%
mean = data.mean(axis = 0)
mean
# Out:
# array([20., 30., 40.])

# %%
std = data.std(axis=0)
std
# Out:
# array([7.07106781, 7.07106781, 7.07106781])
