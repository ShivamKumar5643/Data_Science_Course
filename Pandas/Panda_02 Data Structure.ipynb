# %%
import pandas as pd

# %%
s1 = pd.Series([100,80,700,60])

# %%
s1
# Out:
# 0    100
# 1     80
# 2    700
# 3     60
# dtype: int64

# %%
type(s1)
# Out:
# pandas.Series

# %%
s2 = pd.Series([100,80,700,60],index=["Harry","Shubh","Don","Mafia"])

# %%
s2
# Out:
# Harry    100
# Shubh     80
# Don      700
# Mafia     60
# dtype: int64

# %%
data = {
    "name":["Alice","bob","Charlie"],
    "age":[25,30,35],
    "city":["Delhi","Mumbai","Banglore"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age      city
# 0    Alice   25     Delhi
# 1      bob   30    Mumbai
# 2  Charlie   35  Banglore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='str')
