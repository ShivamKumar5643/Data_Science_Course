# %%
import pandas as pd

# %%
# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Math': [85, 78, 92],
    'Science': [90, 82, 89],
    'English': [88, 85, 94]
}
 
df = pd.DataFrame(data)
 
# Display the DataFrame
print(df)
# Out:
#       Name  Math  Science  English
# 0    Alice    85       90       88
# 1      Bob    78       82       85
# 2  Charlie    92       89       94

# %%
df.melt(id_vars =["Name"],value_vars =["Math","Science","English"],var_name="Subject",value_name="Score")
# Out:
#       Name  Subject  Score
# 0    Alice     Math     85
# 1      Bob     Math     78
# 2  Charlie     Math     92
# 3    Alice  Science     90
# 4      Bob  Science     82
# 5  Charlie  Science     89
# 6    Alice  English     88
# 7      Bob  English     85
# 8  Charlie  English     94

# %%
df.pivot_table(index ="Name",columns = "Subject",values = "Score",aggfunc="mean")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.pivot_table(index ="Name",columns = "Subject",values = "Score",aggfunc="mean")
#
# File /opt/anaconda3/envs/Shivamenv/lib/python3.14/site-packages/pandas/core/frame.py:11159, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#   11141 @Substitution("")
#   11142 @Appender(_shared_docs["pivot_table"])
#   11143 def pivot_table(
#    (...)  11155     **kwargs,
#   11156 ) -> DataFrame:
#   11157     from pandas.core.reshape.pivot import pivot_table
# > 11159     return pivot_table(
#   11160         self,
#   11161         values=values,
#   11162         index=index,
#   11163         columns=columns,
#   11164         aggfunc=aggfunc,
#   11165         fill_value=fill_value,
#   11166         margins=margins,
# ...

# %%
#use melt to long or vertical and pivot to wide and horizontal

# %%
df.columns
# Out:
# Index(['Name', 'Math', 'Science', 'English'], dtype='str')
