# %%
a=5

# %%
b=34

# %%
sum = a+b

# %%
print(sum)
# Out:
# 39

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
s = "Shivam"

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
print (s) # this is coment
# Out:
# Shivam

# %%
a="123"

# %%
b="456"

# %%
print(a+b) # it will concatenate not add ,no need of print here in jupyter notebook.
# Out:
# 123456

# %%
print(int(a)+int(b)) #typecasting,again no need of print.
# Out:
# 579
