# %% [raw]
# ARITHMETIC OPERATORS:-

# %%
a=11
b=8

# %%
a+b
# Out:
# 19

# %%
a-b
# Out:
# 3

# %%
a*b
# Out:
# 88

# %%
a**b
# Out:
# 214358881

# %%
a/b
# Out:
# 1.375

# %%
a//b
# Out:
# 1

# %%
a%b
# Out:
# 3

# %% [raw]
# COMPARISON OPERATORS:-

# %%
a = 9
b=9

# %%
a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %% [raw]
# LOGICAL OPERATORS :-

# %%
c = True
d = False

# %%
c and d
# Out:
# False

# %%
c or d
# Out:
# True

# %%
not(c)
# Out:
# False

# %%
not(d)
# Out:
# True

# %% [raw]
# BITWISE OPERATOR:-

# %%
a=5
b=3

# %%
a&b
# Out:
# 1

# %%
a|b
# Out:
# 7

# %% [raw]
# ASSIGNMENT OPERATOR:-

# %% [raw]
# MEMBERSHIP & IDENTITY OPERATOR:-
