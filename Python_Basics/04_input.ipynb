# %%
a = input("Enter the Vlue of a")#By default it take as a string
# Out:
# Enter the Vlue of a 5

# %%
a
# Out:
# '5'

# %%
b = input("enter the value of b")
# Out:
# enter the value of b 7

# %%
b
# Out:
# '7'

# %%
a+b
# Out:
# '57'

# %%
int(a)+int(b)
# Out:
# 12

# %%
c=input()
# Out:
#  45

# %%
c
# Out:
# '45'

# %%
d= int(input())
# Out:
#  6

# %%
e=int(input())
# Out:
#  3

# %%
d+e
# Out:
# 9
