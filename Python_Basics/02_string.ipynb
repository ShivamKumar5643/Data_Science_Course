# %% [markdown]
# #STRING: it is immutable and collection of characters

# %%
name = "shivam"

# %%
name.capitalize()
# Out:
# 'Shivam'

# %% [markdown]
# name.upper()

# %%
name.upper()
# Out:
# 'SHIVAM'

# %%
name.lower()
# Out:
# 'shivam'

# %%
Name = "    Shivam kumar pandey    "

# %%
Name.strip()
# Out:
# 'Shivam kumar pandey'

# %%
Name.count('a')
# Out:
# 3

# %%
len(name)
# Out:
# 6

# %%
name[0:4]
# Out:
# 'shiv'
