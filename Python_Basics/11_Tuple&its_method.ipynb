# %% [raw]
# TUPLE:-Immutable,orderd

# %%
e = () # empty tuple

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l=[] # empty list

# %%
type(l)
# Out:
# list

# %%
e=(5,64,56,45)

# %%
e
# Out:
# (5, 64, 56, 45)

# %%
len(e)
# Out:
# 4

# %%
e[3]
# Out:
# 45

# %%
#packing
s=("shivam","english",20)
#unpacking
name,subject,marks=s

# %%
subject
# Out:
# 'english'

# %%
marks
# Out:
# 20

# %%
name
# Out:
# 'shivam'
