# %% [raw]
# FILE HANDLING:-

# %%
f = open("text.txt","r")   # when we have to read any file

# %%
f.read()
# Out:
# 'Shivam Kumar Pandey,\nJai Hind Jai Bihar,'

# %%
f.close()

# %%
s = "Jai Bhawani,Jai Shivaji"

# %%
f=open("shivam.txt","w")

# %%
f.write(s)
# Out:
# 23

# %%
f.close()

# %%
f = open("shivam.txt","a")

# %%
f.write("\n this is additional line")
# Out:
# 25

# %%
f.close()
