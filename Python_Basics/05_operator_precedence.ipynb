# %% [markdown]
# OPERATOR PRECEDENCE:- PEMDAS

# %%
r = 10+2*3        #+,-,*,/,//,% are evaluate from left to right

# %%
r
# Out:
# 16

# %%
r1 = (10+2)*3

# %%
r1
# Out:
# 36

# %%
r2 = 2**3**2     #exponentiation is evaluate from right to left

# %%
r2
# Out:
# 512

# %%
r3 = 54*3/23+4-2**5

# %%
r3
# Out:
# -20.956521739130434
