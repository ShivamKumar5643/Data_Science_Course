# %% [raw]
# SETS{} :- unorderd,mutable,unique collection,

# %%
a = {}   # this is empty dictionary

# %%
type (a)
# Out:
# dict

# %%
b = set()        # right way of creating empty set

# %%
type(b)
# Out:
# set

# %%
s = {4,5,33,21,12,21}

# %%
s
# Out:
# {4, 5, 12, 21, 33}

# %%
#typecasting
s1 = set([34,54,34,21,23,32])
s1
# Out:
# {21, 23, 32, 34, 54}

# %%
s.add(35)

# %%
s
# Out:
# {4, 5, 12, 21, 33, 35}

# %%
s.update([34,33,21,11,5])  # when need to add more than one element
s
# Out:
# {4, 5, 11, 12, 21, 33, 34, 35}

# %%
s3 = {23,43,55,67,54,323}

# %%
s3.remove(21)       # if element is not present in set it will throw error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s3.remove(21)       # if element is not present in set it will throw error
#
# KeyError: 21

# %%
s3.discard(21)          # if element is not present in set it will not throw error

# %%
s3.pop()     # remove the random element from the set and return it
# Out:
# 67

# %%
set1 = {43,34,54,45}
set2 = {12,21,34,65}

# %%
set1.union(set2)
# Out:
# {12, 21, 34, 43, 45, 54, 65}

# %%
set1.intersection(set2)
# Out:
# {34}

# %%
sub = {12,21}

# %%
sub.issubset(set2)    # all the element of sub should be presint in the set otherwise return false
# Out:
# True

# %%
set2.issuperset(sub)
# Out:
# True

# %%
set1.symmetric_difference(set2)  # return the element which are not present in both
# Out:
# {12, 21, 43, 45, 54, 65}
