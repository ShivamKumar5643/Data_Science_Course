# %% [raw]
# DICTIONARY{} :- unorderd,mutable,key-value pair

# %%
dict = {}    # empty dict.....

# %%
student = {
    "name":"Shivam",
    "age":20,
    "grade":"A+"}

# %%
student["name"]  # it will throw error if key is not in dictionary
# Out:
# 'Shivam'

# %%
student.get("name")  # it will return if the key is not in dictionary
# Out:
# 'Shivam'

# %%
student["age"] = 21

# %%
student
# Out:
# {'name': 'Shivam', 'age': 21, 'grade': 'A+'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Shivam', 21, 'A+'])

# %%
student.items()
# Out:
# dict_items([('name', 'Shivam'), ('age', 21), ('grade', 'A+')])

# %%
student.update({"name":"Ayush","age":21,"lang":"java"})

# %%
print(student)
# Out:
# {'name': 'Ayush', 'age': 21, 'grade': 'A+', 'lang': 'java'}
