# %% [raw]
# LIST :- Orderd , Mutable

# %%
l = [3,4,5,23]       #List method modify original list and string method return new string;

# %%
l[1]
# Out:
# 4

# %%
l[1]=2

# %%
l[1]
# Out:
# 2

# %%
l.append(22)

# %%
l
# Out:
# [3, 2, 5, 23, 22]

# %%
l2 = [45,65,87]

# %%
l.extend(l2)

# %%
l
# Out:
# [3, 2, 5, 23, 22, 45, 65, 87]

# %%
l.insert(1,4) # insert 4 at index 1

# %%
l
# Out:
# [3, 4, 2, 5, 23, 22, 45, 65, 87]

# %%
l.pop(4)     #delete element of index 4
# Out:
# 23

# %%
l
# Out:
# [3, 4, 2, 5, 22, 45, 65, 87]

# %%
l.index(45)  #index of 1st occurence of the no
# Out:
# 5

# %%
l.count(5)    #count no of same element
# Out:
# 1

# %%
l.sort()     #it sort the original list
l
# Out:
# [2, 3, 4, 5, 22, 45, 65, 87]

# %%
l2 = [3,4,5,21,343,3,4,3]

# %%
sorted(l2)    # it return new sorted list don't change original list
# Out:
# [3, 3, 3, 4, 4, 5, 21, 343]

# %%
l2
# Out:
# [3, 4, 5, 21, 343, 3, 4, 3]

# %%
y = [1,2,3,True,False,[34,43],4]   # list of list or nested list

# %%
y
# Out:
# [1, 2, 3, True, False, [34, 43], 4]

# %%
y[5]
# Out:
# [34, 43]

# %%
y[5][0]
# Out:
# 34

# %%
y[5][1]
# Out:
# 43

# %%
list1 = [34,43,23,32]

# %%
list2 = [12,21,23,32,45,54]

# %%
list1+list2   #List concatenation it return new list
# Out:
# [34, 43, 23, 32, 12, 21, 23, 32, 45, 54]

# %%
if 23 in list1:          # checking membership of element in the list
    print("yes")
# Out:
# yes

# %%
32 in list2
# Out:
# True

# %%
s = "Shivam kumar pandey"   #spliting the string into list

# %%
s.split(" ")
# Out:
# ['Shivam', 'kumar', 'pandey']
