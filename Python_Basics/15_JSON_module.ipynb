# %%
import json

# %%
obj = {"name":"Shivam","age":20,"course":"Btech"}

# %%
json.dumps(obj)     #it return object as a string
# Out:
# '{"name": "Shivam", "age": 20, "course": "Btech"}'

# %%
d = '{"name": "Shivam", "age": 20, "course": "Btech"}'

# %%
json.loads(d)       # it returb as a python object or dictionary
# Out:
# {'name': 'Shivam', 'age': 20, 'course': 'Btech'}

# %%
file = open("data.json","w")

# %%
json.dump(obj,file)

# %%
file.close()
